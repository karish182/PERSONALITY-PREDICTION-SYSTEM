# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("data-final.csv",sep='\t')

# %%
print("Raw Data Shape : ", df.shape)
# Out:
# Raw Data Shape :  (1015341, 110)

# %%
df.head()
# Out:
#    EXT1  EXT2  EXT3  EXT4  EXT5  EXT6  EXT7  EXT8  EXT9  EXT10  ...  \
# 0   4.0   1.0   5.0   2.0   5.0   1.0   5.0   2.0   4.0    1.0  ...
# 1   3.0   5.0   3.0   4.0   3.0   3.0   2.0   5.0   1.0    5.0  ...
# 2   2.0   3.0   4.0   4.0   3.0   2.0   1.0   3.0   2.0    5.0  ...
# 3   2.0   2.0   2.0   3.0   4.0   2.0   2.0   4.0   1.0    4.0  ...
# 4   3.0   3.0   3.0   3.0   5.0   3.0   3.0   5.0   3.0    4.0  ...
#
#               dateload  screenw  screenh  introelapse  testelapse  endelapse  \
# 0  2016-03-03 02:01:01    768.0   1024.0          9.0       234.0          6
# 1  2016-03-03 02:01:20   1360.0    768.0         12.0       179.0         11
# 2  2016-03-03 02:01:56   1366.0    768.0          3.0       186.0          7
# 3  2016-03-03 02:02:02   1920.0   1200.0        186.0       219.0          7
# 4  2016-03-03 02:02:57   1366.0    768.0          8.0       315.0         17
#
#    IPC  country  lat_appx_lots_of_err  long_appx_lots_of_err
# ...

# %%
print(df.columns.tolist())
# Out:
# ['EXT1', 'EXT2', 'EXT3', 'EXT4', 'EXT5', 'EXT6', 'EXT7', 'EXT8', 'EXT9', 'EXT10', 'EST1', 'EST2', 'EST3', 'EST4', 'EST5', 'EST6', 'EST7', 'EST8', 'EST9', 'EST10', 'AGR1', 'AGR2', 'AGR3', 'AGR4', 'AGR5', 'AGR6', 'AGR7', 'AGR8', 'AGR9', 'AGR10', 'CSN1', 'CSN2', 'CSN3', 'CSN4', 'CSN5', 'CSN6', 'CSN7', 'CSN8', 'CSN9', 'CSN10', 'OPN1', 'OPN2', 'OPN3', 'OPN4', 'OPN5', 'OPN6', 'OPN7', 'OPN8', 'OPN9', 'OPN10', 'EXT1_E', 'EXT2_E', 'EXT3_E', 'EXT4_E', 'EXT5_E', 'EXT6_E', 'EXT7_E', 'EXT8_E', 'EXT9_E', 'EXT10_E', 'EST1_E', 'EST2_E', 'EST3_E', 'EST4_E', 'EST5_E', 'EST6_E', 'EST7_E', 'EST8_E', 'EST9_E', 'EST10_E', 'AGR1_E', 'AGR2_E', 'AGR3_E', 'AGR4_E', 'AGR5_E', 'AGR6_E', 'AGR7_E', 'AGR8_E', 'AGR9_E', 'AGR10_E', 'CSN1_E', 'CSN2_E', 'CSN3_E', 'CSN4_E', 'CSN5_E', 'CSN6_E', 'CSN7_E', 'CSN8_E', 'CSN9_E', 'CSN10_E', 'OPN1_E', 'OPN2_E', 'OPN3_E', 'OPN4_E', 'OPN5_E', 'OPN6_E', 'OPN7_E', 'OPN8_E', 'OPN9_E', 'OPN10_E', 'dateload', 'screenw', 'screenh', 'introelapse', 'testelapse', 'endelapse', 'IPC', 'cou
# ...

# %% [markdown]
# BIG FIVE(OCEAN MODEL)  (Extraversion, Emotional Stability, Agreeableness, Conscientiousness, and Openness)

# %%
# Columns to keep for personality prediction
keep_columns = ['EXT1', 'EXT2', 'EXT3', 'EXT4', 'EXT5', 'EXT6', 'EXT7', 'EXT8', 'EXT9', 'EXT10',
                'EST1', 'EST2', 'EST3', 'EST4', 'EST5', 'EST6', 'EST7', 'EST8', 'EST9', 'EST10',
                'AGR1', 'AGR2', 'AGR3', 'AGR4', 'AGR5', 'AGR6', 'AGR7', 'AGR8', 'AGR9', 'AGR10',
                'CSN1', 'CSN2', 'CSN3', 'CSN4', 'CSN5', 'CSN6', 'CSN7', 'CSN8', 'CSN9', 'CSN10',
                'OPN1', 'OPN2', 'OPN3', 'OPN4', 'OPN5', 'OPN6', 'OPN7', 'OPN8', 'OPN9', 'OPN10']

# Drop unnecessary columns
df_cleaned = df[keep_columns]

# Print the cleaned dataset
print("Cleaned dataset columns:")
print(df_cleaned.columns.tolist())
# Out:
# Cleaned dataset columns:
# ['EXT1', 'EXT2', 'EXT3', 'EXT4', 'EXT5', 'EXT6', 'EXT7', 'EXT8', 'EXT9', 'EXT10', 'EST1', 'EST2', 'EST3', 'EST4', 'EST5', 'EST6', 'EST7', 'EST8', 'EST9', 'EST10', 'AGR1', 'AGR2', 'AGR3', 'AGR4', 'AGR5', 'AGR6', 'AGR7', 'AGR8', 'AGR9', 'AGR10', 'CSN1', 'CSN2', 'CSN3', 'CSN4', 'CSN5', 'CSN6', 'CSN7', 'CSN8', 'CSN9', 'CSN10', 'OPN1', 'OPN2', 'OPN3', 'OPN4', 'OPN5', 'OPN6', 'OPN7', 'OPN8', 'OPN9', 'OPN10']

# %%
# Check for missing values
print("Missing values per column:")
print(df_cleaned.isnull().sum())
# Out:
# Missing values per column:
# EXT1     1783
# EXT2     1783
# EXT3     1783
# EXT4     1783
# EXT5     1783
# EXT6     1783
# EXT7     1783
# EXT8     1783
# EXT9     1783
# EXT10    1783
# EST1     1783
# EST2     1783
# EST3     1783
# EST4     1783
# EST5     1783
# EST6     1783
# EST7     1783
# EST8     1783
# EST9     1783
# EST10    1783
# AGR1     1783
# AGR2     1783
# AGR3     1783
# AGR4     1783
# AGR5     1783
# AGR6     1783
# AGR7     1783
# AGR8     1783
# AGR9     1783
# AGR10    1783
# CSN1     1783
# CSN2     1783
# CSN3     1783
# CSN4     1783
# CSN5     1783
# CSN6     1783
# CSN7     1783
# CSN8     1783
# CSN9     1783
# CSN10    1783
# OPN1     1783
# OPN2     1783
# OPN3     1783
# OPN4     1783
# OPN5     1783
# OPN6     1783
# OPN7     1783
# OPN8     1783
# OPN9     1783
# OPN10    1783
# dtype: int64

# %%
# Create a boolean mask to identify missing values
missing_mask = df_cleaned.isnull()

# Print the locations of missing values
print("Locations of missing values:")
print(missing_mask[missing_mask])
# Out:
# Locations of missing values:
#         EXT1 EXT2 EXT3 EXT4 EXT5 EXT6 EXT7 EXT8 EXT9 EXT10  ... OPN1 OPN2  \
# 0        NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN  ...  NaN  NaN
# 1        NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN  ...  NaN  NaN
# 2        NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN  ...  NaN  NaN
# 3        NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN  ...  NaN  NaN
# 4        NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN  ...  NaN  NaN
# ...      ...  ...  ...  ...  ...  ...  ...  ...  ...   ...  ...  ...  ...
# 1015336  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN  ...  NaN  NaN
# 1015337  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN  ...  NaN  NaN
# 1015338  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN  ...  NaN  NaN
# 1015339  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN  ...  NaN  NaN
# 1015340  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN  ...  NaN  NaN
#
#         OPN3 OPN4 OPN5 OPN6 OPN7 OPN8 OPN9 OPN10
# ...

# %%
# Drop rows with any missing values
df_cleaned = df_cleaned.dropna()

# %%
# Check if any missing values remain
print("\nRemaining missing values per column:")
print(df_cleaned.isnull().sum())
# Out:
# Remaining missing values per column:
# EXT1     0
# EXT2     0
# EXT3     0
# EXT4     0
# EXT5     0
# EXT6     0
# EXT7     0
# EXT8     0
# EXT9     0
# EXT10    0
# EST1     0
# EST2     0
# EST3     0
# EST4     0
# EST5     0
# EST6     0
# EST7     0
# EST8     0
# EST9     0
# EST10    0
# AGR1     0
# AGR2     0
# AGR3     0
# AGR4     0
# AGR5     0
# AGR6     0
# AGR7     0
# AGR8     0
# AGR9     0
# AGR10    0
# CSN1     0
# CSN2     0
# CSN3     0
# CSN4     0
# CSN5     0
# CSN6     0
# CSN7     0
# CSN8     0
# CSN9     0
# CSN10    0
# OPN1     0
# OPN2     0
# OPN3     0
# OPN4     0
# OPN5     0
# OPN6     0
# OPN7     0
# OPN8     0
# OPN9     0
# OPN10    0
# dtype: int64

# %%
df_cleaned.shape
# Out:
# (1013558, 50)

# %%
df_cleaned.to_csv("data-final-cleaned.csv", sep='\t', index=False)

# %%
ext_questions = {'EXT1' : 'I am the life of the party',
                 'EXT2' : 'I dont talk a lot',
                 'EXT3' : 'I feel comfortable around people',
                 'EXT4' : 'I keep in the background',
                 'EXT5' : 'I start conversations',
                 'EXT6' : 'I have little to say',
                 'EXT7' : 'I talk to a lot of different people at parties',
                 'EXT8' : 'I dont like to draw attention to myself',
                 'EXT9' : 'I dont mind being the center of attention',
                 'EXT10': 'I am quiet around strangers'}

est_questions = {'EST1' : 'I get stressed out easily',
                 'EST2' : 'I am relaxed most of the time',
                 'EST3' : 'I worry about things',
                 'EST4' : 'I seldom feel blue',
                 'EST5' : 'I am easily disturbed',
                 'EST6' : 'I get upset easily',
                 'EST7' : 'I change my mood a lot',
                 'EST8' : 'I have frequent mood swings',
                 'EST9' : 'I get irritated easily',
                 'EST10': 'I often feel blue'}

agr_questions = {'AGR1' : 'I feel little concern for others',
                 'AGR2' : 'I am interested in people',
                 'AGR3' : 'I insult people',
                 'AGR4' : 'I sympathize with others feelings',
                 'AGR5' : 'I am not interested in other peoples problems',
                 'AGR6' : 'I have a soft heart',
                 'AGR7' : 'I am not really interested in others',
                 'AGR8' : 'I take time out for others',
                 'AGR9' : 'I feel others emotions',
                 'AGR10': 'I make people feel at ease'}

csn_questions = {'CSN1' : 'I am always prepared',
                 'CSN2' : 'I leave my belongings around',
                 'CSN3' : 'I pay attention to details',
                 'CSN4' : 'I make a mess of things',
                 'CSN5' : 'I get chores done right away',
                 'CSN6' : 'I often forget to put things back in their proper place',
                 'CSN7' : 'I like order',
                 'CSN8' : 'I shirk my duties',
                 'CSN9' : 'I follow a schedule',
                 'CSN10': 'I am exacting in my work'}

opn_questions = {'OPN1' : 'I have a rich vocabulary',
                 'OPN2' : 'I have difficulty understanding abstract ideas',
                 'OPN3' : 'I have a vivid imagination',
                 'OPN4' : 'I am not interested in abstract ideas',
                 'OPN5' : 'I have excellent ideas',
                 'OPN6' : 'I do not have a good imagination',
                 'OPN7' : 'I am quick to understand things',
                 'OPN8' : 'I use difficult words',
                 'OPN9' : 'I spend time reflecting on things',
                 'OPN10': 'I am full of ideas'}

# Group Names and Columns
EXT = [column for column in df_cleaned if column.startswith('EXT')]
EST = [column for column in df_cleaned if column.startswith('EST')]
AGR = [column for column in df_cleaned if column.startswith('AGR')]
CSN = [column for column in df_cleaned if column.startswith('CSN')]
OPN = [column for column in df_cleaned if column.startswith('OPN')]

# %% [markdown]
# VISUALISATION OF QUENTIONS AND THEIR DISTRIBUTION

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Function to plot the distribution of a personality trait
def plot_trait_distribution(columns, questions, trait_name):
    plt.figure(figsize=(12, 6))
    for i, column in enumerate(columns):
        plt.subplot(2, 5, i + 1)
        sns.countplot(data=df, x=column)
        plt.title(questions[column], fontsize=10)
        plt.xticks(rotation=45)
    plt.tight_layout()
    plt.suptitle(f"Distribution of {trait_name} Questions", fontsize=16)
    plt.show()

# %%
# Plot distributions for each personality trait
plot_trait_distribution(EXT, ext_questions, 'Extraversion')

# %%
plot_trait_distribution(EST, est_questions, 'Emotional Stability')

# %%
plot_trait_distribution(AGR, agr_questions, 'Agreeableness')

# %%
plot_trait_distribution(CSN, csn_questions, 'Conscientiousness')

# %%
plot_trait_distribution(OPN, opn_questions, 'Openness')

# %% [markdown]
# FEATURE ENGINEERING (scaling-average score,min-max)

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler


# Create a list of feature columns
feature_columns = ['EXT1', 'EXT2', 'EXT3', 'EXT4', 'EXT5', 'EXT6', 'EXT7', 'EXT8', 'EXT9', 'EXT10',
                   'EST1', 'EST2', 'EST3', 'EST4', 'EST5', 'EST6', 'EST7', 'EST8', 'EST9', 'EST10',
                   'AGR1', 'AGR2', 'AGR3', 'AGR4', 'AGR5', 'AGR6', 'AGR7', 'AGR8', 'AGR9', 'AGR10',
                   'CSN1', 'CSN2', 'CSN3', 'CSN4', 'CSN5', 'CSN6', 'CSN7', 'CSN8', 'CSN9', 'CSN10',
                   'OPN1', 'OPN2', 'OPN3', 'OPN4', 'OPN5', 'OPN6', 'OPN7', 'OPN8', 'OPN9', 'OPN10']

# Separate features and target variable
X = df[feature_columns]
y = df['target']  # Assuming 'target' is the name of your target variable

# Create a MinMaxScaler object
scaler = MinMaxScaler()

# Fit and transform the feature matrix
X_scaled = scaler.fit_transform(X)

# Convert the scaled feature matrix back to a DataFrame
X_scaled_df = pd.DataFrame(X_scaled, columns=feature_columns)
